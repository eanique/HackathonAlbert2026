# %% [markdown]
# # Sujet 3 — Mise en jambe (Q1 → Q12)
#
# > Équipe **BDD-MinArm** · Hackathon Albert School 2026 · Ministère des Armées.
# > Échauffement sur les `*_small.csv` (~20 lignes chacun).
#
# Ce notebook est une présentation **exécutée** : il appelle le livrable `reponses_mise_en_jambe.py` (toute la logique est dans `src/`), puis affiche l'artefact produit (`outputs/mise_en_jambe_q10.png`).

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from reponses_mise_en_jambe import main as mej_main

# %% [markdown]
# ## Exécution du livrable `reponses_mise_en_jambe.py`

# %%
mej_main()
# Out:
# INFO src.load: ships : 20 navires (dont 0 suspects)
# INFO src.load: radio : 20 signatures, 20 MMSI distincts
# INFO src.load: ais : 20 lignes, 20 MMSI, AIS_OFF=11
# ...
#   SUJET 3 — Mise en jambe (petit dataset, ~20 lignes)
# ...
#
# ### Q1 — Structure des fichiers
# Champs communs ships ↔ radio : ['mmsi']
# Colonnes ships : 9 | radio : 10 | ais : 8
#
# ### Q2 — Navires
# Plus long : MOL Triumph (MMSI 244710008) — 362.3 m.
# Pavillon Panama : 4 navire(s).
#
# ### Q3 — Signatures radio
# Fréquence max : 161.95 MHz.
# Modulation FM : 11 signature(s).
#
# ### Q4 — AIS
# Lignes AIS désactivé : 11
# Navire le plus rapide : MMSI 244710005 — 27.3 nœuds.
#
# ### Q5 — Liens navires ↔ signatures
# Navires avec ≥ 1 signature radio : 20/20
#
# ### Q6 — Liens navires ↔ AIS
# Navires avec ≥ 1 ligne AIS : 20
# Avec AIS mais sans radio : []
#
# ### Q7 — Écart AIS↔radio simple (seuil 0.001°)
# Lignes avec écart > 0.001° : 20 (20 navires)
#
# ### Q8 — Données manquantes / orphelins
# ...

# %% [markdown]
# ## Artefact — Q10 : histogramme des vitesses + navires par pavillon

# %%
from IPython.display import Image
Image(filename=str(ROOT / 'outputs' / 'mise_en_jambe_q10.png'))

# %% [markdown]
# > Les questions ouvertes Q11 (hypothèses sur l'AIS désactivé / les écarts de position) et Q12 (champs manquants, automatisation) sont développées dans `rapport_generalisation.md`.
